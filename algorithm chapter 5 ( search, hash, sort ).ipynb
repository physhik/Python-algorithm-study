# %%
# ordered sequenitial search

def sequentialSearch(slist, item): # my coding, working for both direction
    found = False
    for element in slist:
        if element == item:
            found = True
        elif element > item and ascend(slist):
            return found
        elif element < item and not ascend(slist):
            return found
    
    
def ascend(slist):
    if slist[0]>slist[1]:
        return False
    else:
        return True


def sequentialSearch1(alist, item): # arthor's suggestion
    pos = 0
    found = False
    stop = False
    while pos < len(alist) and not found and not stop:
        if alist[pos] == item:
            found = True
        else:
            if alist[pos] > item:
                stop = True
            else:
                pos = pos+1

    return found


def sequentialSearch2(slist, item): # my coding, modified with stop. Doesn't change complexity
    found = False
    stop = False
    for element in slist:
        if element == item and not found and not stop:
            found = True
        elif element > item and ascend(slist):
            stop = True
        elif element < item and not ascend(slist):
            stop = True
            
    return found
       
    
import time     

def main(): # Whose is faster?
    testlist = [42, 32, 17, 13, 8, 2, 1, 0]

    start = time.time()
    print sequentialSearch2(testlist, 16)
    print sequentialSearch2(testlist, 17)
    print sequentialSearch2(testlist, 31)
    end = time.time()
    print end-start

    start = time.time()
    print sequentialSearch1(testlist, 16)
    print sequentialSearch1(testlist, 17)
    print sequentialSearch1(testlist, 31)
    end = time.time()
    print end-start
    
main()

# %%
testlist = [0, 1, 2]

testlist[1+1:], testlist[:1]

# %%
# arthor's

def binarySearch(alist, item):
    first = 0
    last = len(alist)-1
    found = False

    while first<=last and not found:
        midpoint = (first + last)//2
        if alist[midpoint] == item:
            found = True
        else:
            if item < alist[midpoint]:
                last = midpoint-1
            else:
                first = midpoint+1

    return found

testlist = [0, 1, 2, 8, 13, 17, 32, 42]
print binarySearch(testlist, 3)
print binarySearch(testlist, 42)
print binarySearch(testlist, 7.5)
# Out:
# False
# True
# False

# %%
# my coding 
# recursive 
# both directionally working
def binarySearch( blist, item):
    index = len(blist)
    hindex = index/2
    found = False
    if blist[hindex]==item:
        found = True
    else:
        if blist[hindex] < item and not hindex+1 == index and ascend(blist): 
            # 뒤의 가정. 무한 루프에 빠지거나 인덱스 범위를 벗어나는 에러가 뜨지 않게 하기 위해 
            return binarySearch(blist[hindex+1:], item)
        elif blist[hindex] > item and not hindex-1 == index and ascend(blist):
            return binarySearch(blist[:hindex], item)
        elif blist[hindex] < item and not hindex+1 == index and not ascend(blist):
            return binarySearch(blist[:hindex], item)
        elif blist[hindex] > item and not hindex-1 == index and not ascend(blist):
            return binarySearch(blist[hindex+1:], item)
        elif blist[0] == item:
            found = True
    
    return found
        

def ascend(slist):
    if slist[0]>slist[1]:
        return False
    else:
        return True    

#testlist = [0, 1, 2, 8, 13, 17, 32, 42]
testlist = [42,32,17,13,8,2,1,0]
print binarySearch(testlist, 0)
print binarySearch(testlist, 32)
print binarySearch(testlist, 42)
print binarySearch(testlist, 7.5)

# %%
# author's
# recursive 
def binarySearch( blist, item):
    index = len(blist)
    hindex = index/2
    if index == 0: # this is smart and different from mine, to keep list in the range
        return False
    else:
        if blist[hindex]==item: # base
            return True
        else: # recursion
            
            if blist[hindex] > item:
                return binarySearch(blist[:hindex], item)
            else:
                return binarySearch(blist[hindex+1:], item)  

testlist = [0, 1, 2, 8, 13, 17, 32, 42]
print binarySearch(testlist, 0)
print binarySearch(testlist, 32)
print binarySearch(testlist, 42)
print binarySearch(testlist, 7.5)

# %%
#my code 

def hash(str, tablesize):
    return sum([ord(x) for x in str])%tablesize

hash('cat', 11)

# %%
#arthor's

def hash(astring, tablesize):
    sum = 0
    for pos in range(len(astring)):
        sum = sum + ord(astring[pos])

    return sum%tablesize


hash('cat', 11)

# %%
class HashTable:
    def __init__(self): # create 11 None-slots
        self.size = 11
        self.slots = [None] * self.size
        self.data = [None] * self.size
        
    def hashfunction(self,key,size):
        return key%size

    def rehash(self,oldhash,size): #linear rehash 1-probe
        return (oldhash+1)%size

    


    def __getitem__(self,key): # H[index] working 
        return self.get(key)

    def __setitem__(self,key,data): # setting H[index]=key is available
        self.put(key,data)



    def get(self,key):
        startslot = self.hashfunction(key,len(self.slots))

        data = None
        stop = False
        found = False
        position = startslot
        while self.slots[position] != None and  \
                       not found and not stop:
            if self.slots[position] == key:
                found = True
                data = self.data[position]
            else:
                position=self.rehash(position,len(self.slots))
                if position == startslot:
                    stop = True
        return data




    def put(self,key,data):
        hashvalue = self.hashfunction(key,len(self.slots))

        if self.slots[hashvalue] == None:
            self.slots[hashvalue] = key
            self.data[hashvalue] = data
        else:
            if self.slots[hashvalue] == key:
                self.data[hashvalue] = data  #replace
            else:
                newhash = self.rehash(hashvalue,len(self.slots))
                while self.slots[newhash] != None and \
                      self.slots[newhash] != key:
                    newhash = self.rehash(newhash,len(self.slots)) #recursion

                if self.slots[newhash] == None:
                    self.slots[newhash]=key
                    self.data[newhash]=data
                else:
                    self.data[newhash] = data #replace data with the same key

# %%
H=HashTable()
H[54]="cat"
H[10]="dog"
H[21]="bird"
H[0]="cow"
H[3]="rat"

# %%
H.slots
# Out:
# [10, 21, 0, 3, None, None, None, None, None, None, 54]

# %%
H.data
# Out:
# ['dog', 'bird', 'cow', 'rat', None, None, None, None, None, None, 'cat']

# %%
H.size
# Out:
# 11

# %%
def shortbubbleSort(blist):
    exchange = True
    num = len(blist)-1
    while exchange and num>0:
        exchange = False
        for j in range(num):
            if blist[j]>blist[j+1]:
                exchange = True
                temp = blist[j]
                blist[j]=blist[j+1]
                blist[j+1]=temp
        num = num -1
            

            
blist  = [54,26,93,17,77,31,44,55,20,1]


shortbubbleSort(blist)
blist
# Out:
# [1, 17, 20, 26, 31, 44, 54, 55, 77, 93]

# %%
# my code 
def selectSort(slist):
    for i in range(len(slist)-1):
        maxindex, max = mymax(slist[:-1-i])
        if max>slist[len(slist)-1-i]:
            temp = slist[len(slist)-1-i]
            slist[len(slist)-1-i]=max
            slist[maxindex]=temp
        
    
        
def mymax(slist):
    maxindex=0
    max=slist[maxindex]


    for i in range(len(slist)-1):
        if slist[i] > max:
            maxindex=i
            max=slist[i]

    return maxindex, slist[maxindex]
    
slist=[1, 54, 93, 17, 77, 26, 44, 55, 20, 31]

selectSort(slist)
slist

# %%
# author's
def selectionSort(alist):
   for fillslot in range(len(alist)-1,0,-1):
       positionOfMax=0
       for location in range(1,fillslot+1):
           if alist[location]>alist[positionOfMax]:
               positionOfMax = location

       temp = alist[fillslot]
       alist[fillslot] = alist[positionOfMax]
       alist[positionOfMax] = temp

alist = [54,26,93,17,77,31,44,55,20]
selectionSort(alist)
print(alist)

# %%
# my code 
def insertSort(ilist):
    alist=ilist
    for i in range(1,len(ilist)):
        alist[i]=ilist[i]


        for j in range(i,0,-1):
            if alist[j-1]>alist[j]:
                temp = alist[j]
                alist[j] = alist[j-1]
                alist[j-1]=temp
                    
                
    ilist= alist 
    
                
      
ilist =[54,26,93,17,77,31,44,55,20]
insertSort(ilist)
ilist
# Out:
# [17, 20, 26, 31, 44, 54, 55, 77, 93]

# %%
# author's
def insertionSort(alist):
   for index in range(1,len(alist)):

     currentvalue = alist[index]
     position = index

     while position>0 and alist[position-1]>currentvalue:
         alist[position]=alist[position-1]
         position = position-1

     alist[position]=currentvalue

alist = [54,26,93,17,77,31,44,55,20]
insertionSort(alist)
print(alist)
# Out:
# [17, 20, 26, 31, 44, 54, 55, 77, 93]

# %%
# my code

def shellSort(slist, div):
    
    for i in range(div):
        alist=[]
        for j in range(div):
            if i+div*j < len(slist):
               
                alist.append(slist[i+div*j])
                insertionSort(alist)
                print "sorted sublist:", alist

        for j in range(div):
            if i+div*j < len(slist):
                slist[i+div*j]=alist[j]
    print "shell sorted list with div",div,":", slist
    insertionSort(slist)


slist=[54,26,93,17,77,31,44,55,20]
shellSort(slist,3)
print "full sorted list:", slist
# Out:
# sorted sublist: [54]
# sorted sublist: [17, 54]
# sorted sublist: [17, 44, 54]
# sorted sublist: [26]
# sorted sublist: [26, 77]
# sorted sublist: [26, 55, 77]
# sorted sublist: [93]
# sorted sublist: [31, 93]
# sorted sublist: [20, 31, 93]
# shell sorted list with div 3 : [17, 26, 20, 44, 55, 31, 54, 77, 93]
# full sorted list: [17, 20, 26, 31, 44, 54, 55, 77, 93]

# %%
def shellSort(alist):
    sublistcount = len(alist)//2
    while sublistcount > 0:

      for startposition in range(sublistcount):
        gapInsertionSort(alist,startposition,sublistcount)

      print("After increments of size",sublistcount,
                                   "The list is",alist)

      sublistcount = sublistcount // 2

def gapInsertionSort(alist,start,gap):
    for i in range(start+gap,len(alist),gap):

        currentvalue = alist[i]
        position = i

        while position>=gap and alist[position-gap]>currentvalue:
            alist[position]=alist[position-gap]
            position = position-gap

        alist[position]=currentvalue

alist = [54,26,93,17,77,31,44,55,20]
shellSort(alist)
print(alist)
# Out:
# ('After increments of size', 4, 'The list is', [20, 26, 44, 17, 54, 31, 93, 55, 77])
# ('After increments of size', 2, 'The list is', [20, 17, 44, 26, 54, 31, 77, 55, 93])
# ('After increments of size', 1, 'The list is', [17, 20, 26, 31, 44, 54, 55, 77, 93])
# [17, 20, 26, 31, 44, 54, 55, 77, 93]

# %%
# my coding 
def mergeSort(alist):
    if len(alist)>1:  # 쪼개는 무한 룹을 만들지 않기 위해 
        size = len(alist)    
        mid=size/2
        mergeSort(alist[:mid])
        mergeSort(alist[mid:])

        dlist=[]
        i,j=0,0
        
        print (alist[:mid]),(alist[mid:])
        while i<len(alist[:mid]) and j<len(alist[mid:]):
            if dlist1[i]<dlist2[j]:
                dlist.append(dlist1[i])
                i = i+1
            else:
                dlist.append(dlist2[j])
                j=j+1
                
        if not dlist1[i] in dlist:
            dlist.append(dlist1[i])

        for i in range(len(dlist)):
            alist[i]=dlist[i]

    
        

alist = [54,26,93,17,77,31,44,55,20]
mergeSort(alist)
alist
# Out:
# [54] [26]
# [93] [17]
# [54, 26] [93, 17]
# [77] [31]
# [55] [20]
# [44] [55, 20]
# [77, 31] [44, 55, 20]
# [54, 26, 93, 17] [77, 31, 44, 55, 20]
# [17, 20, 26, 31, 44, 54, 55, 77, 93]

# %%
def mergeSort(alist):
    print("Splitting ",alist)
    if len(alist)>1:
        mid = len(alist)//2
        lefthalf = alist[:mid]
        righthalf = alist[mid:]

        mergeSort(lefthalf)
        mergeSort(righthalf)

        i=0
        j=0
        k=0
        while i < len(lefthalf) and j < len(righthalf):
            if lefthalf[i] < righthalf[j]:
                alist[k]=lefthalf[i]
                i=i+1
            else:
                alist[k]=righthalf[j]
                j=j+1
            k=k+1

        while i < len(lefthalf):
            alist[k]=lefthalf[i]
            i=i+1
            k=k+1

        while j < len(righthalf):
            alist[k]=righthalf[j]
            j=j+1
            k=k+1
    print("Merging ",alist)

alist = [54,26,93,17,77,31,44,55,20]
mergeSort(alist)
print(alist)
# Out:
# ('Splitting ', [54, 26, 93, 17, 77, 31, 44, 55, 20])
# ('Splitting ', [54, 26, 93, 17])
# ('Splitting ', [54, 26])
# ('Splitting ', [54])
# ('Merging ', [54])
# ('Splitting ', [26])
# ('Merging ', [26])
# ('Merging ', [26, 54])
# ('Splitting ', [93, 17])
# ('Splitting ', [93])
# ('Merging ', [93])
# ('Splitting ', [17])
# ('Merging ', [17])
# ('Merging ', [17, 93])
# ('Merging ', [17, 26, 54, 93])
# ('Splitting ', [77, 31, 44, 55, 20])
# ('Splitting ', [77, 31])
# ('Splitting ', [77])
# ('Merging ', [77])
# ('Splitting ', [31])
# ('Merging ', [31])
# ('Merging ', [31, 77])
# ('Splitting ', [44, 55, 20])
# ('Splitting ', [44])
# ('Merging ', [44])
# ('Splitting ', [55, 20])
# ('Splitting ', [55])
# ('Merging ', [55])
# ('Splitting ', [20])
# ('Merging ', [20])
# ('Merging ', [20, 55])
# ('Merging ', [20, 44, 55])
# ('Merging ', [20, 31, 44, 55, 77])
# ('Merging ', [17, 20, 26, 31, 44, 54, 55, 77, 93])
# [17, 20, 26, 31, 44, 54, 55, 77, 93]

# %%
# my code. Not working yet

def quickSort(qlist):
    if len(qlist)>1:
        splitpoint = partition(qlist)

        quickSort(qlist[:splitpoint])
        quickSort(qlist[splitpoint+1:])
        
def partition(qlist):
    pivotvalue = qlist[0]
    leftmark, rightmark = 1, len(qlist)-1
    while leftmark<rightmark:
        if qlist[leftmark] < pivotvalue and qlist[rightmark]<pivotvalue:
            leftmark +=1
                      
        elif qlist[leftmark] < pivotvalue and qlist[rightmark]>pivotvalue:
            leftmark +=1
            rightmark -=1
            
        elif qlist[leftmark] > pivotvalue and qlist[rightmark]>pivotvalue:
            rightmark -=1
            
        else: 
            temp = qlist[leftmark]
            qlist[leftmark]=qlist[rightmark]
            qlist[rightmark]=temp
            leftmark +=1
            rightmark -=1

                
        
        
qlist=[54,26,93,17,77,31,44,55,20]
quickSort(qlist)
qlist
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-337-9ebf7aee98de> in <module>()
#      31
#      32 qlist=[54,26,93,17,77,31,44,55,20]
# ---> 33 quickSort(qlist)
#      34 qlist
#      35
#
# <ipython-input-337-9ebf7aee98de> in quickSort(qlist)
#       3         splitpoint = partition(qlist)
#       4
# ----> 5         quickSort(qlist[:splitpoint])
#       6         quickSort(qlist[splitpoint+1:])
#       7
#
# <ipython-input-337-9ebf7aee98de> in quickSort(qlist)
#       3         splitpoint = partition(qlist)
#       4
# ----> 5         quickSort(qlist[:splitpoint])
#       6         quickSort(qlist[splitpoint+1:])
#       7
#
# <ipython-input-337-9ebf7aee98de> in quickSort(qlist)
#       3         splitpoint = partition(qlist)
#       4
# ----> 5         quickSort(qlist[:splitpoint])
#       6         quickSort(qlist[splitpoint+1:])
#       7
#
# ...

# %%
def quickSort(alist):
   quickSortHelper(alist,0,len(alist)-1)

def quickSortHelper(alist,first,last):
   if first<last:

       splitpoint = partition(alist,first,last)

       quickSortHelper(alist,first,splitpoint-1)
       quickSortHelper(alist,splitpoint+1,last)


def partition(alist,first,last):
   pivotvalue = alist[first]

   leftmark = first+1
   rightmark = last

   done = False
   while not done:

       while leftmark <= rightmark and alist[leftmark] <= pivotvalue:
           leftmark = leftmark + 1

       while alist[rightmark] >= pivotvalue and rightmark >= leftmark:
           rightmark = rightmark -1

       if rightmark < leftmark:
           done = True
       else:
           temp = alist[leftmark]
           alist[leftmark] = alist[rightmark]
           alist[rightmark] = temp

   temp = alist[first]
   alist[first] = alist[rightmark]
   alist[rightmark] = temp


   return rightmark

alist = [54,26,93,17,77,31,44,55,20]
quickSort(alist)
print(alist)
# Out:
# [17, 20, 26, 31, 44, 54, 55, 77, 93]

# %%
def quickSort(alist,first,last):
   if first<last:

       splitpoint = partition(alist,first,last)

       quickSort(alist,first,splitpoint-1)
       quickSort(alist,splitpoint+1,last)
       print alist[first:splitpoint]
       print alist[splitpoint+1:last]



def partition(alist,first,last):
   pivotvalue = alist[first]

   leftmark = first+1
   rightmark = last

   done = False
   while not done:

       while leftmark <= rightmark and alist[leftmark] <= pivotvalue:
           leftmark = leftmark + 1

       while alist[rightmark] >= pivotvalue and rightmark >= leftmark:
           rightmark = rightmark -1

       if rightmark < leftmark:
           done = True
       else:
           temp = alist[leftmark]
           alist[leftmark] = alist[rightmark]
           alist[rightmark] = temp

   temp = alist[first]
   alist[first] = alist[rightmark]
   alist[rightmark] = temp


   return rightmark

alist = [54,26,93,17,77,31,44,55,20]
quickSort(alist,0,len(alist)-1)
alist
# Out:
# [20]
# []
# []
# [20]
# [17, 20, 26]
# []
# [55]
# []
# [17, 20, 26, 31, 44]
# [55, 77]
# [17, 20, 26, 31, 44, 54, 55, 77, 93]
